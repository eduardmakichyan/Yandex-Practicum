# %% [markdown]
# Привет, Эдуард!
#
# Меня зовут Вячеслав Погорелый, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на "ты", если не против)
#
# Но если это не удобно - дай знать, и мы перейдем на "вы". Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Я отметил комментарии и замечания разным цветом далее по тексту markdown:
#
# ---
# <div class="alert alert-block alert-danger">
#
# ### Ошибка
#
# Критическое замечание, которые следует исправить.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
# ### Совет
#
# Замечание\совет на будущее.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
# ### Успех
#
# Когда всё сделано правильно.
# </div>
#
#
#
# Будет здорово, если для ответов ты выберешь любой **<font color="maroon">читабельный и заметный цвет</font>**, так мне будет проще все проверить.
#
#
# При доработке проекта попрошу тебя сохранить и не видоизменять заметки ревьюера, это осложняет повторную проверку.

# %% [markdown]
# # Комментарий студента
# <font color='green'> Рад познакомиться, мне тоже будет удобнее на ты. Спасибо за комментарии , я посторался учесть ошибки и исправить их. Доп. комментарии я поставил зеленым цветом.

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# В нашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#  Цель : научиться определять рыночную стоимость объектов недвижимости.
# Необходимо провести исследовательский анализ данных, который поможет установить параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Спасибо тебе за небольшое оглавление к проекту.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# Импортируем библиотеки и читаем файл с таблицей, сохраняем его в переменную.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Старайся разделять импорт библиотек от основного кода.

# %% [markdown]
# Смотрим общую информацию о таблице.

# %%
data.info
# Out:
# <bound method DataFrame.info of        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0                2.70          16.0         51.0      8          NaN  ...
# 1                 NaN          11.0         18.6      1          NaN  ...
# 2                 NaN           5.0         34.3      4          NaN  ...
# 3                 NaN          14.0          NaN      9          NaN  ...
# 4                3.03          14.0         32.0     13          NaN  ...
# ...               ...           ...          ...    ...          ...  ...
# 23694            3.70           5.0         73.3      3          NaN  ...
# 23695             NaN           5.0         38.0      4          NaN  ...
# 23696             NaN           3.0         29.7      1          NaN  ...
# 23697            3.00          17.0          NaN     12          NaN  ...
# 23698            2.50           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# 0             25.00      NaN      Санкт-Петербург           18863.0
# 1             11.00      2.0       посёлок Шушары           12817.0
# 2              8.30      0.0      Санкт-Петербург           21741.0
# 3               NaN      0.0      Санкт-Петербург           28098.0
# 4             41.00      NaN      Санкт-Петербург           31856.0
# ...             ...      ...                  ...               ...
# 23694         13.83      NaN      Санкт-Петербург           24665.0
# 23695          8.50      NaN                Тосно               NaN
# 23696           NaN      NaN     село Рождествено               NaN
# 23697         23.30      2.0      Санкт-Петербург           39140.0
# 23698          9.00      NaN  поселок Новый Учхоз               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.0               1.0          482.0               2.0
# 1                 18603.0               0.0            NaN               0.0
# 2                 13933.0               1.0           90.0               2.0
# 3                  6800.0               2.0           84.0               3.0
# 4                  8098.0               2.0          112.0               1.0
# ...                   ...               ...            ...               ...
# 23694              4232.0               1.0          796.0               3.0
# 23695                 NaN               NaN            NaN               NaN
# 23696                 NaN               NaN            NaN               NaN
# 23697             10364.0               2.0          173.0               3.0
# 23698                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 0              755.0              NaN
# 1                NaN             81.0
# 2              574.0            558.0
# 3              234.0            424.0
# 4               48.0            121.0
# ...              ...              ...
# 23694          381.0              NaN
# 23695            NaN             45.0
# 23696            NaN              NaN
# 23697          196.0            602.0
# 23698            NaN              NaN
#
# [23699 rows x 22 columns]>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Первичная информация о данных получена.

# %% [markdown]
# Проверяем кол-во явных дубликатов. Их нет.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Построение гистограммы для всех числовых столбцов таблицы.

# %%
data.hist(figsize=(15,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <font color='green'>При первичном знакомстве с данными мы видим , что есть пропуски, отсутсвуют явные дубликаты. </font>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Чтобы убрать текстовые предупреждения, используй plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Надо оставить небольшой промежуточный вывод по итогу знакомства с данными

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Исправлено

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Изучение пропусков в данных

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Для визуализации пропусков используй https://russianblogs.com/article/5001266235/

# %% [markdown]
# Заполнение всех пропусков в столбце балкон - '0'. Скорее всего , если человек не указал кол-во балконов - их нет.

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Согласен. Раз не указали количество балконов, то их могло и не быть

# %% [markdown]
# Пропуски высоты потолков можно заполнить медиальным значением для всего столбца.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Поскольку высота потолков достаточно стандартизированна, то можно заменить медианой.

# %% [markdown]
# Заполняем пропущенные значения жилой площади медиальным отношением жилой площади к общей площади для пропущенных значений.

# %%
data.loc[data['living_area'].isna(), 'living_area'] = (data['living_area'] / data['total_area']).median() * data.loc[data['living_area'].isna(), 'total_area']

# %% [markdown]
# Для пропущенных значений в площади кухни делаем тоже самое.

# %%
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = (data['kitchen_area'] / data['total_area']).median() * data.loc[data['kitchen_area'].isna(), 'total_area']

# %% [markdown]
# В тех строках, где кол-во комнат равно нулю, заполняем пропуски для столбца с апартаментами 'True', в остальных 'False'.

# %%
data.loc[(data['rooms'] == 0)&(data['is_apartment'].isna()), 'is_apartment']  = data.fillna(True)

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# В этом случае тоже согласен.

# %% [markdown]
# Пропуски общего кол-ва этажей заполним медиальным отношением общего кол-ва этажей к этажу самой квартиры.

# %%
data.loc[data['floors_total'].isna(), 'floors_total'] = (data['floors_total'] / data['floor']).median() * data.loc[data['floors_total'].isna(), 'floor']

# %% [markdown]
# Удаляем пропуски в названии населенного пункта.

# %%
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Здесь пропусков мало и логично от них избавиться.

# %% [markdown]
# Проверяем результат, в основных категориях больше не осталось пропусков.
# Оставшиеся пропуски оставим как есть, они не повлияют на дальнейшее исследование.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5534
# cityCenters_nearest      5511
# parks_around3000         5510
# parks_nearest           15586
# ponds_around3000         5510
# ponds_nearest           14565
# days_exposition          3180
# dtype: int64

# %% [markdown]
# Пропуски в данных могут быть результатом нескольких факторов: <br>
# 1. Произошел технический сбой при обработке или хранении данных.
# 2. Пропуски в данных могут быть результатом человеческой ошибки(неправильно внесли данные).
# 3. Скорее всего пропуски связанны с некоректной системой сбора данных, например пользователь не обязан заполнить все поля для оформления обьявления.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Причины возникновения высказаны

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23650 non-null  float64
#  6   floors_total          23650 non-null  float64
#  7   living_area           23650 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          23650 non-null  float64
#  13  balcony               23650 non-null  float64
#  14  locality_name         23650 non-null  object
#  15  airports_nearest      18116 non-null  float64
#  16  cityCenters_nearest   18139 non-null  float64
#  17  parks_around3000      18140 non-null  float64
#  18  parks_nearest         8064 non-null   float64
#  19  ponds_around3000      18140 non-null  float64
#  20  ponds_nearest         9085 non-null   float64
#  21  days_exposition       20470 non-null  float64
# dtypes: bool(3), float64(14), int64(3), object(2)
# memory usage: 3.7+ MB

# %% [markdown]
# Смотрим на формат записи даты и времени.

# %%
data['first_day_exposition'].head(20)
# Out:
# 0     2019-03-07T00:00:00
# 1     2018-12-04T00:00:00
# 2     2015-08-20T00:00:00
# 3     2015-07-24T00:00:00
# 4     2018-06-19T00:00:00
# 5     2018-09-10T00:00:00
# 6     2017-11-02T00:00:00
# 7     2019-04-18T00:00:00
# 8     2018-05-23T00:00:00
# 9     2017-02-26T00:00:00
# 10    2017-11-16T00:00:00
# 11    2018-08-27T00:00:00
# 12    2016-06-30T00:00:00
# 13    2017-07-01T00:00:00
# 14    2016-06-23T00:00:00
# 15    2017-11-18T00:00:00
# 16    2017-11-23T00:00:00
# 17    2016-09-09T00:00:00
# 18    2017-01-27T00:00:00
# 19    2019-01-09T00:00:00
# Name: first_day_exposition, dtype: object

# %% [markdown]
# Меняем формат записи даты и времени и смотрим на результат.
# Нужно было поменять формат времени с 'object' на 'datetime64' для того, чтобы впоследствии была возможность добавить новые столбцы(день недели,месяц,год).

# %%
data._is_copy = None
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Тобой использован оптимальный метод перевода к временному формату

# %%
data['first_day_exposition'].head(20)
# Out:
# 0    2019-03-07
# 1    2018-12-04
# 2    2015-08-20
# 3    2015-07-24
# 4    2018-06-19
# 5    2018-09-10
# 6    2017-11-02
# 7    2019-04-18
# 8    2018-05-23
# 9    2017-02-26
# 10   2017-11-16
# 11   2018-08-27
# 12   2016-06-30
# 13   2017-07-01
# 14   2016-06-23
# 15   2017-11-18
# 16   2017-11-23
# 17   2016-09-09
# 18   2017-01-27
# 19   2019-01-09
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Выявляем неявные дубликаты в названиях населенных пунктов и приводим их одному формату.

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа','городской поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции','поселок станции')
data['locality_name'] = data['locality_name'].str.replace('деревня','село')

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'село Кудрово', 'Коммунар', 'Колпино',
#        'городской поселок Красный Бор', 'Гатчина', 'село Федоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'село Новое Девяткино',
#        'поселок Металлострой', 'городской поселок Лебяжье',
#        'городской поселок Сиверский', 'поселок Молодцово',
#        'городской поселок Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск', 'село Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'село Куттузи', 'поселок Аннино', 'городской поселок Ефимовский',
#        'поселок Плодовое', 'село Заклинье', 'поселок Торковичи',
#        'поселок Первомайское', 'Красное Село', 'поселок Понтонный',
#        'Сясьстрой', 'село Старая', 'село Лесколово', 'поселок Новый Свет',
#        'Сланцы', 'село Путилово', 'Ивангород', 'Мурино', 'Шлиссельбург',
#        'Никольское', 'Зеленогорск', 'Сосновый Бор', 'село Оржицы',
#        'село Кальтино', 'Кудрово', 'поселок Романовка', 'поселок Бугры',
#        'городской поселок Рощино', 'Кириши', 'Луга', 'Волосово',
#        'Отрадное', 'село Павлово', 'поселок Оредеж', 'село Копорье',
#        'поселок Молодежное', 'Тихвин', 'поселок Победа', 'село Нурма',
#        'городской поселок Синявино', 'Тосно', 'поселок Стрельна',
#        'Бокситогорск', 'поселок Александровская', 'село Лопухинка',
#        'Пикалево', 'поселок Терволово', 'городской поселок Советский',
#        'Подпорожье', 'поселок Петровское', 'городской поселок Токсово',
#        'поселок Сельцо', 'городской поселок Вырица', 'село Кипень',
#        'село Келози', 'село Вартемяги', 'поселок Тельмана',
#        'поселок Севастьяново', 'городской поселок Большая Ижора',
#        'городской поселок Павлово', 'село Агалатово',
#        'поселок Новогорелово', 'городской поселок Лесогорский',
#        'село Лаголово', 'поселок Цвелодубово', 'городской поселок Рахья',
#        'село Белогорка', 'поселок Заводской',
#        'городской поселок Новоселье', 'село Большие Колпаны',
#        'село Горбунки', 'село Батово', 'село Заневка', 'село Иссад',
#        'Приморск', 'городской поселок Федоровское', 'село Мистолово',
#        'Новая Ладога', 'поселок Зимитицы', 'поселок Барышево',
#        'село Разметелево', 'городской поселок имени Свердлова',
#        'село Пеники', 'поселок Рябово', 'село Пудомяги',
#        'поселок станции Корнево', 'село Низино', 'село Бегуницы',
#        'поселок Поляны', 'городской поселок Мга', 'поселок Елизаветино',
#        'городской поселок Кузнечное', 'село Колтуши',
#        'поселок Запорожское', 'село Гостилицы', 'село Малое Карлино',
#        'поселок Мичуринское', 'городской поселок имени Морозова',
#        'поселок Песочный', 'поселок Сосново', 'село Аро',
#        'поселок Ильичево', 'городской поселок Тайцы', 'село Малое Верево',
#        'село Извара', 'поселок станции Вещево', 'село Паша',
#        'село Калитино', 'городской поселок Ульяновка', 'село Чудской Бор',
#        'городской поселок Дубровка', 'село Мины', 'поселок Войсковицы',
#        'село Коркино', 'поселок Ропша', 'городской поселок Приладожский',
#        'поселок Щеглово', 'поселок Гаврилово', 'Лодейное Поле',
#        'село Рабитицы', 'городской поселок Никольский', 'село Кузьмолово',
#        'село Малые Колпаны', 'поселок Петро-Славянка',
#        'городской поселок Назия', 'поселок Репино', 'поселок Углово',
#        'поселок Старая Малукса', 'садовое товарищество Рахья',
#        'село Меньково', 'село Старые Бегуницы', 'поселок Саперный',
#        'поселок Семрино', 'поселок Глажево', 'поселок Кобринское',
#        'село Гарболово', 'село Юкки', 'поселок станции Приветнинское',
#        'село Мануйлово', 'село Пчева', 'поселок Цвылево',
#        'поселок Мельниково', 'поселок Пудость', 'поселок Усть-Луга',
#        'Светогорск', 'Любань', 'поселок Селезнево',
#        'городской поселок Рябово', 'Каменногорск', 'село Кривко',
#        'поселок Глебычево', 'село Парицы', 'поселок Жилпоселок',
#        'поселок Войскорово', 'село Никольское', 'поселок Стеклянный',
#        'городской поселок Важины', 'поселок Мыза-Ивановка',
#        'село Русско-Высоцкое', 'городской поселок Форносово',
#        'село Старая Ладога', 'поселок Житково',
#        'городской поселок Виллози', 'село Лампово', 'село Шпаньково',
#        'село Лаврики', 'поселок Сумино', 'поселок Возрождение',
#        'село Старосиверская', 'поселок Кикерино', 'село Старое Хинколово',
#        'поселок Пригородный', 'поселок Торфяное',
#        'городской поселок Будогощь', 'поселок Суходолье',
#        'поселок Красная Долина', 'село Хапо-Ое',
#        'городской поселок Дружная Горка', 'поселок Лисий Нос',
#        'село Яльгелево', 'село Рождествено', 'село Старополье',
#        'поселок Левашово', 'село Сяськелево', 'село Камышовка',
#        'садоводческое некоммерческое товарищество Лесная Поляна',
#        'село Хязельки', 'поселок Жилгородок', 'село Ялгино',
#        'поселок Новый Учхоз', 'поселок Гончарово', 'поселок Почап',
#        'поселок Саперное', 'поселок Платформа 69-й километр',
#        'поселок Каложицы', 'село Фалилеево', 'село Пельгора',
#        'село Торошковичи', 'поселок Белоостров', 'поселок Алексеевка',
#        'поселок Серебрянский', 'поселок Лукаши', 'село Щеглово',
#        'село Тарасово', 'поселок Кингисеппский', 'поселок Ушаки',
#        'село Котлы', 'село Сижно', 'село Торосово',
#        'поселок Форт Красная Горка', 'село Новолисино',
#        'поселок станции Громово', 'село Глинка', 'село Старая Пустошь',
#        'поселок Коммунары', 'поселок Починок',
#        'городской поселок Вознесенье', 'село Разбегаево',
#        'поселок Гладкое', 'поселок Тесово-4', 'село Бор',
#        'поселок Коробицыно', 'село Большая Вруда', 'село Курковицы',
#        'поселок Кобралово', 'село Суоранда',
#        'городской поселок Кондратьево', 'коттеджный поселок Счастье',
#        'поселок Любань', 'село Реброво', 'село Зимитицы',
#        'село Тойворово', 'поселок Семиозерье', 'поселок Лесное',
#        'поселок Совхозный', 'поселок Ленинское', 'поселок Суйда',
#        'село Нижние Осельки', 'поселок станции Свирь', 'поселок Перово',
#        'Высоцк', 'поселок Гарболово', 'село Шум', 'поселок Котельский',
#        'поселок станции Лужайка', 'село Большая Пустомержа',
#        'поселок Красносельское', 'село Вахнова Кара', 'село Пижма',
#        'коттеджный поселок Кивеннапа Север', 'поселок Ромашки',
#        'село Каськово', 'село Куровицы', 'поселок Плоское',
#        'поселок Кирпичное', 'село Ям-Тесово', 'село Раздолье',
#        'село Терпилицы', 'поселок Шугозеро', 'село Ваганово',
#        'поселок Пушное', 'садовое товарищество Садко',
#        'поселок Усть-Ижора', 'село Выскатка',
#        'городской поселок Свирьстрой', 'поселок Громово', 'село Кисельня',
#        'село Трубников Бор', 'поселок Калитино', 'поселок Высокоключевой',
#        'садовое товарищество Приладожский',
#        'поселок Пансионат Зеленый Бор', 'село Ненимяки',
#        'село Снегиревка', 'село Рапполово', 'село Пустынка',
#        'поселок Рабитицы', 'село Большой Сабск', 'село Русско',
#        'село Лупполово', 'село Большое Рейзино', 'село Малая Романовка',
#        'поселок Дружноселье', 'поселок Пчевжа', 'поселок Володарское',
#        'село Нижняя', 'коттеджный поселок Лесное', 'село Тихковицы',
#        'село Борисова Грива', 'поселок Дзержинского'], dtype=object)

# %%
len(data) # сколько строк осталось после предобработки
# Out:
# 23650

# %% [markdown]
# <font color='green'> В ходе предобработки были выполненны следующие шаги:
# 1. Обнарауженны и заполненны пропуски там, где это было возможно.
# 2. Был изменен тип данных для формата записи времени.
# 3. Были обнаруженны и исправленны неявные дубликаты в названиях населенных пунктов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Надо было здесь вывести сколько значений у тебя осталось после проработки.
#
#
# А еще не хватает промежуточного вывода после Предобработки.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# Вот так лучше

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# # Добавляем новые столбцы

# %% [markdown]
# Столбец с ценой квадратного метра

# %%
data['square_meter_price'] = (data['last_price'] / data['total_area']).round(2)

# %%
data['square_meter_price'].head()
# Out:
# 0    120370.37
# 1     82920.79
# 2     92785.71
# 3    408176.10
# 4    100000.00
# Name: square_meter_price, dtype: float64

# %% [markdown]
# Столбец с днем недели размещения объявления.

# %%
data['expositions_weekday'] = data['first_day_exposition'].dt.weekday

# %%
data['expositions_weekday'].head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    4
# 4    1
# Name: expositions_weekday, dtype: int64

# %% [markdown]
# Столбец с месяцом размещения.

# %%
data['expositions_month'] = data['first_day_exposition'].dt.month

# %%
data['expositions_month'].head()
# Out:
# 0     3
# 1    12
# 2     8
# 3     7
# 4     6
# Name: expositions_month, dtype: int64

# %% [markdown]
# Столбец с годом размещения.

# %%
data['expositions_year'] = data['first_day_exposition'].dt.year

# %%
data['expositions_year'].head()
# Out:
# 0    2019
# 1    2018
# 2    2015
# 3    2015
# 4    2018
# Name: expositions_year, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Достаточно простым методом ты выделяешь временные отрезки из данных

# %% [markdown]
# Столбец с обозначением типа этажа : 'первый' , 'последний' , 'другой'.

# %%
def floorstype(row) : 
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else: 
        return 'другой'
data['floor_type'] = data.apply(floorstype, axis=1)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Простая, удобная и понятная функция категоризаии

# %%
data['floor_type'].head()
# Out:
# 0    другой
# 1    первый
# 2    другой
# 3    другой
# 4    другой
# Name: floor_type, dtype: object

# %% [markdown]
# Столбец с расстоянием до центра города в км.

# %%
data['city_center_km'] = round(data['cityCenters_nearest']/1000)

# %%
data['city_center_km'].head()
# Out:
# 0    16.0
# 1    19.0
# 2    14.0
# 3     7.0
# 4     8.0
# Name: city_center_km, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Теперь данные готовы к дальнейшему исследованию.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Изучим столбец с общей площадью квартиры.

# %%
data['total_area'].describe()
# Out:
# count    23650.000000
# mean        60.329069
# std         35.661808
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['total_area'].hist()
plt.title('total_area')
# Out:
# Text(0.5, 1.0, 'total_area')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Давай сразу привыкнем оформлять графики правильно. Для этого не забывай давать им названия. Сделать это можно командой title()

# %%
plt.ylim(0,300)
data.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %%
data[data['total_area'] > 250]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 155               8   96000000.0       317.0           2017-07-07      4
# 464              15   66571000.0       280.3           2015-06-11      6
# 581              20   65000000.0       365.0           2019-03-18      7
# 660               3   49950000.0       483.9           2017-10-04      7
# 793              20  135000000.0       310.0           2018-05-22      4
# ...             ...          ...         ...                  ...    ...
# 22238            12   19500000.0       287.5           2017-12-27      7
# 22345             8   53250000.0       290.0           2017-09-25      6
# 22494             7   91075000.0       491.0           2017-05-27      5
# 22835            20   29000000.0       275.0           2018-07-27      5
# 23005            20   30750000.0       297.5           2018-09-09      6
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 155              3.50           3.0   183.000000      3         False  ...
# 464              5.20           8.0   159.500000      7         False  ...
# 581              2.90           7.0   207.268863      7         False  ...
# 660              3.20           6.0   312.500000      4         False  ...
# 793              3.30           5.0   250.000000      2         False  ...
# ...               ...           ...          ...    ...           ...  ...
# 22238            2.65           4.0   183.700000      3         False  ...
# 22345            2.90           7.0   180.000000      6         False  ...
# 22494            4.20           9.0   274.000000      9         False  ...
# 22835            2.65          17.0   180.000000     17         False  ...
# 23005            3.14           4.0   181.800000      2         False  ...
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 155            508.0               3.0          366.0             62.0
# 464            187.0               1.0          616.0            578.0
# 581            378.0               3.0           58.0              NaN
# 660            461.0               3.0           22.0            391.0
# 793            295.0               3.0          190.0            342.0
# ...              ...               ...            ...              ...
# 22238          578.0               1.0          853.0             90.0
# 22345          427.0               0.0            NaN            134.0
# 22494          116.0               0.0            NaN            115.0
# 22835          570.0               3.0          502.0             91.0
# 23005          189.0               3.0           40.0             42.0
#
#       square_meter_price  expositions_weekday  expositions_month  \
# 155            302839.12                    4                  7
# 464            237499.11                    3                  6
# 581            178082.19                    0                  3
# 660            103223.81                    2                 10
# 793            435483.87                    1                  5
# ...                  ...                  ...                ...
# 22238           67826.09                    2                 12
# 22345          183620.69                    0                  9
# 22494          185488.80                    5                  5
# 22835          105454.55                    4                  7
# 23005          103361.34                    6                  9
#
#        expositions_year  floor_type  city_center_km
# 155                2017   последний             2.0
# 464                2015      другой             7.0
# 581                2019   последний             2.0
# 660                2017      другой             1.0
# 793                2018      другой             7.0
# ...                 ...         ...             ...
# 22238              2017      другой             5.0
# 22345              2017      другой             6.0
# 22494              2017   последний             6.0
# 22835              2018   последний            13.0
# 23005              2018      другой             1.0
#
# [112 rows x 28 columns]

# %% [markdown]
# Видно , что в данных есть выбросы. Они плохо повлияют на результат исследования. Оставим только те квартиры , плозадь которых меньше 250 кв.м . 112 строк придется удалить, это незначительная часть данных.

# %%
data = data.loc[data['total_area'] < 250]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# От выбросов исзбавились

# %%
data['total_area'].describe()
# Out:
# count    23534.000000
# mean        58.933078
# std         28.782378
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        249.900000
# Name: total_area, dtype: float64

# %%
data.boxplot(column='total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посмотрим на жилую площадь.

# %%
data['living_area'].describe()
# Out:
# count    23534.00000
# mean        33.77112
# std         18.77799
# min          2.00000
# 25%         19.00000
# 50%         30.00000
# 75%         42.00000
# max        220.00000
# Name: living_area, dtype: float64

# %%
data['living_area'].hist()
plt.title('living_area')
# Out:
# Text(0.5, 1.0, 'living_area')

# %%
data.boxplot(column='living_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Построем диграмму рассеяния. Поскольку жилая площадь напрямую зависит от общей площади.
# Диаграмма показывает , что есть прямая зависимость между общей площадью и жилой. Следовательно данные в порядке.

# %%
data.plot(x='total_area', y='living_area', grid=True, kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='living_area'>

# %% [markdown]
# <font color='green'>На графике видно, что от выбросов получилось избавиться.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# Было бы правильно тут писать еще выводы по графикам на очищенных данных. Мы же графики как раз для написания выводов используем.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Комментарий ревьюера ver.2
#
# #### Успех
#
# И тут отлично

# %% [markdown]
# Взглянем на площадь кухни.

# %%
data['kitchen_area'].describe()
# Out:
# count    23534.000000
# mean        10.351154
# std          5.531485
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.900000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %%
data['kitchen_area'].hist()
plt.title('kitchen_area')
# Out:
# Text(0.5, 1.0, 'kitchen_area')

# %%
data.boxplot(column='kitchen_area')
# Out:
# <AxesSubplot:>

# %%
data.plot(x='total_area', y='kitchen_area', kind='scatter', grid=True)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='kitchen_area'>

# %% [markdown]
# Видим , что есть большие выбросы , которые могут испортить анализ. Оставим для исследования только те квартиры , где площадь кухни меньше 60 кв.м .

# %%
data = data[data['kitchen_area'] < 60]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Все верно, квратиры более 60 метров это редкость.

# %%
data.boxplot(column='kitchen_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='green'> Сократили кол-во выбросов до приемлимого кол-ва.

# %% [markdown]
# Обратим свой взор на цену на момент снятия с публикации. Для удобства переведем цену в миллионы.

# %%
data._is_copy = None
data['last_price'] /= 1000000

# %%
data['last_price'].describe()
# Out:
# count    23517.000000
# mean         6.153250
# std          6.859093
# min          0.012190
# 25%          3.400000
# 50%          4.600000
# 75%          6.700000
# max        330.000000
# Name: last_price, dtype: float64

# %%
data['last_price'].hist()
plt.title('last_price')
# Out:
# Text(0.5, 1.0, 'last_price')

# %%
plt.ylim(0,50)
data.boxplot(column='last_price')
# Out:
# <AxesSubplot:>

# %%
data[data['last_price'] > 40].count()
# Out:
# total_images            108
# last_price              108
# total_area              108
# first_day_exposition    108
# rooms                   108
# ceiling_height          108
# floors_total            108
# living_area             108
# floor                   108
# is_apartment            108
# studio                  108
# open_plan               108
# kitchen_area            108
# balcony                 108
# locality_name           108
# airports_nearest        105
# cityCenters_nearest     106
# parks_around3000        106
# parks_nearest            88
# ponds_around3000        106
# ponds_nearest            93
# days_exposition          81
# square_meter_price      108
# expositions_weekday     108
# expositions_month       108
# expositions_year        108
# floor_type              108
# city_center_km          106
# dtype: int64

# %% [markdown]
# Оставим только те квартиры , цена которых меньше 40000000 руб. , остальные придется удалить. Скорее всего это не типичная недвижимость.
# Если ее оставить она сильно исказит результаты исследования.

# %%
data = data.loc[data['last_price'] < 40]

# %%
len(data) # проверим сколько строк осталось в таблице
# Out:
# 23400

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Полезно тут будет выводить сколько осталось данных от первоначальных. Это полезно делать для самопроверки. Мы должны оставить не менее 90% данных для дальнейшего анализа

# %%
data.boxplot(column='last_price')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Обратимся к столбцы с кол-вом комнат.

# %%
data['rooms'].describe()
# Out:
# count    23400.000000
# mean         2.040897
# std          1.019278
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         14.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].hist()
plt.title('rooms')
# Out:
# Text(0.5, 1.0, 'rooms')

# %%
data.boxplot(column='rooms')
# Out:
# <AxesSubplot:>

# %%
data.plot(x='total_area', y='rooms', kind='scatter', grid=True)
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='rooms'>

# %% [markdown]
# Оставим в таблице только те квартиры , где меньше 8 комнат.

# %%
data = data.loc[data['rooms'] < 8]

# %%
data['rooms'].hist()
plt.title('rooms')
# Out:
# Text(0.5, 1.0, 'rooms')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# В целом, у нас распределение по комнатам выглядит реалистично

# %% [markdown]
# Взглянем на высоту поталков.

# %%
data['ceiling_height'].describe()
# Out:
# count    23387.000000
# mean         2.719904
# std          0.992187
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видим , что в данных есть аномальные значения. Постараемся их исправить и оставить.

# %%
data['ceiling_height'].hist()
plt.title('ceiling_height')
# Out:
# Text(0.5, 1.0, 'ceiling_height')

# %%
data.boxplot(column='ceiling_height')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Заполним аномальные значения медиальными.

# %%
data._is_copy = None
data.loc[(data['ceiling_height'] < 2)|(data['ceiling_height'] > 3.5), 'ceiling_height'] = data['ceiling_height'].median()

# %%
data['ceiling_height'].describe()
# Out:
# count    23387.000000
# mean         2.680320
# std          0.172366
# min          2.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          3.500000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist()
plt.title('ceiling_height')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Потолки более 3 метров могут говорить о наличии дореволюционной застройки

# %% [markdown]
# Гистограмма для типа этажа.

# %%
data['floor_type'].hist()
plt.title('floor_type')
plt.show()

# %% [markdown]
# Общее кол-во этажей.

# %%
data['floors_total'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Если ты рассмотришь график чуть подробнее, то увидишь тут выбросы. Они говорят о том, что у насмного квартир типовой застройки

# %%
data['floors_total'].describe()
# Out:
# count    23387.000000
# mean        10.740642
# std          6.639161
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Расстояние до центра города в метрах.

# %%
data['cityCenters_nearest'].hist()
plt.title('cityCenters_nearest')
# Out:
# Text(0.5, 1.0, 'cityCenters_nearest')

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    17881.000000
# mean     14314.527040
# std       8590.249231
# min        181.000000
# 25%       9488.000000
# 50%      13171.000000
# 75%      16360.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Расстояние до ближайшего парка.

# %%
data['parks_nearest'].hist()
plt.title('parks_nearest')
# Out:
# Text(0.5, 1.0, 'parks_nearest')

# %% [markdown]
# # Изучим cколько дней было размещенно обьявление до снятия.

# %%
data['days_exposition'].hist(bins=200)
plt.title('days_exposition')
# Out:
# Text(0.5, 1.0, 'days_exposition')

# %%
data['days_exposition'].describe()
# Out:
# count    20266.000000
# mean       179.445574
# std        218.526742
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data.boxplot(column='days_exposition')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='green'> Видим , что есть выбросы. Возможно владелец забыл снять обьявление после продаже , также , возможно , это специфическая недвижимость и продается она не так быстро.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ### Комментарий ревьюера
#
# #### Ошибка
#
# А тут надо расммотреть график подробнее. На нем будет несколько выбросов. Надо показать их на графике и высказаться о причинах возникновения.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # Комментарий ревьюера ver.2
#
# #### Совет
#
# А здесь вот надо бы еще дать пояснения откуда появились эти выбивающиеся значения

# %% [markdown]
# Среднее кол-во дней до снятия с публикации.

# %%
data['days_exposition'].mean()
# Out:
# 179.44557386756142

# %% [markdown]
# Медиальное кол-во дней до снятия с публикации.

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# Можно считать продажи до месяца достаточно быстрыми. Продажи от 500 дней можно принять за слишком долгие.

# %% [markdown]
# # Изучим какие факторы больше всего влияют на общую (полную) стоимость объекта.

# %% [markdown]
# ## Посмотрим как цена зависит от общей площади.

# %%
data.plot(x='total_area', y='last_price', grid=True, kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %%
data['total_area'].corr(data['last_price']) #корелляция между общей площадью и ценой
# Out:
# 0.7828123148392451

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Классный метод для показа зависимости на графике.

# %% [markdown]
# Мы видим ярко выраженную зависимоть между общей площадью и ценой продажи недвижимости.

# %% [markdown]
# ## Изучим зависимость цены от жилой площади

# %%
data.plot(x='living_area', y='last_price', kind='scatter', grid=True)
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %%
data['living_area'].corr(data['last_price']) #корелляция между жилой площадью и ценой
# Out:
# 0.6840280563730513

# %% [markdown]
# Заметно, что карелляция жилой площади и ценой ниже чем общей площади.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# А вот здесь небольшая связь все же наблюдается

# %% [markdown]
# ## Изучим зависимость цены и площади кухни.

# %%
data.plot(x='kitchen_area', y='last_price', grid=True, kind='scatter')
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %%
data['kitchen_area'].corr(data['last_price']) #корелляция между площадью кухни и ценой
# Out:
# 0.6165075003740805

# %% [markdown]
# Корелляция между ценой недвижимости и площадью кухни ниже чем у общей площади и жилой площади.

# %% [markdown]
# ## Изучим есть ли связь между кол-вом комнат и ценой.

# %%
data['rooms'].corr(data['last_price'])
# Out:
# 0.49787643567195744

# %% [markdown]
# Сводная таблица по кол-ву комнат и медиальной цене.

# %%
rooms_price_pivot = data.pivot_table(index='rooms', values='last_price', aggfunc='median')
rooms_price_pivot
# Out:
#        last_price
# rooms
# 0        2.700000
# 1        3.600000
# 2        4.752981
# 3        6.150000
# 4        8.822500
# 5       12.500000
# 6       16.495000
# 7       17.800000

# %%
rooms_price_pivot.plot.bar()
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
data.plot(x='total_area', y='rooms', kind='scatter', grid=True) #График зависимости площади от комнат.
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='rooms'>

# %% [markdown]
# Видно , что цена недвижимости повышается при увеличении числа комнат. Это связанно ,в основном, с увеличением общей площади недвижимости при увеличение кол-во комнат.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Тут логично, поддержу

# %% [markdown]
# ## Проверим , есть ли зависимость между типом этажа ('первый','последний','другой') и ценой.

# %% [markdown]
# Сделаем сводную таблицу , в которой будут медиальные значения цены недвижимости по типу этажа.

# %%
floor_type_price_pivot = data.pivot_table(index='floor_type', values='last_price', aggfunc='median')
floor_type_price_pivot
# Out:
#             last_price
# floor_type
# другой            4.80
# первый            3.90
# последний         4.25

# %%
floor_type_price_pivot.plot.bar() #столбчатый график
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# Благодоря таблице и столбчатому графику мы видим , что :
#     1. Первый этаж является самым дешевым.
#     2. За ним идет последний этаж.
#     3. Самыми дорогими являются этажи между первым и последним.

# %% [markdown]
# ## Посмторим есть ли звязь между ценой и датой размещения(день недели, месяц, год).

# %% [markdown]
# ### День недели и цена.

# %% [markdown]
# Сделаем сводную таблицу сгруппированную по дням недели и медиальным значением цены для каждого дня.

# %%
weekday_price_pivot = data.pivot_table(index='expositions_weekday', values='last_price', aggfunc='median')
weekday_price_pivot
# Out:
#                      last_price
# expositions_weekday
# 0                          4.60
# 1                          4.70
# 2                          4.67
# 3                          4.60
# 4                          4.55
# 5                          4.50
# 6                          4.50

# %%
weekday_price_pivot.plot.bar(ylim=(0,5.5)) #столбчатый график
# Out:
# <AxesSubplot:xlabel='expositions_weekday'>

# %% [markdown]
# Мы можем увидеть , что цена практически не зависит от дня недели. Разве что к концу недели она ниже, но не значительно.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Все так и есть

# %% [markdown]
# ### Месяц и цена.

# %% [markdown]
# Сделаем сводную таблицу сгруппированную по месяцам и медиальным значением цены для каждого месяца.

# %%
month_price_pivot = data.pivot_table(index='expositions_month', values='last_price', aggfunc='median')
month_price_pivot
# Out:
#                    last_price
# expositions_month
# 1                      4.6000
# 2                      4.6000
# 3                      4.6225
# 4                      4.7750
# 5                      4.5000
# 6                      4.3995
# 7                      4.6000
# 8                      4.5500
# 9                      4.6500
# 10                     4.5500
# 11                     4.6500
# 12                     4.6410

# %%
month_price_pivot.plot.bar(figsize=(7,6), ylim=(0,5.5)) #столбчатый график
# Out:
# <AxesSubplot:xlabel='expositions_month'>

# %% [markdown]
# Как и в случае с днями недели, значения от месяца к месяцу меняются не слишком сильно. Можно выделить только лишь июнь(6 месяц), цены в этом месяце ниже чем во всех остальных.

# %% [markdown]
# ### Год и цена.

# %% [markdown]
# Сделаем сводную таблицу сгруппированную по году и медиальным значением цены для каждого года.

# %%
year_price_pivot = data.pivot_table(index='expositions_year', values='last_price', aggfunc='median')
year_price_pivot
# Out:
#                   last_price
# expositions_year
# 2014                 7.47656
# 2015                 5.23450
# 2016                 4.50000
# 2017                 4.50000
# 2018                 4.55000
# 2019                 5.00000

# %%
year_price_pivot.plot.bar() #столбчатый график.
# Out:
# <AxesSubplot:xlabel='expositions_year'>

# %% [markdown]
# Благодаря сводной таблице и столбчатому графику мы видим , что : 1. После 2014г цены на недвижимость значительно упали(7.5 млн. для 2014г). 2. После 2015г тоже заметно снижение цен, но уже не настолько резко(5.2 млн. 2015г). 3. В 2016г, 2017г, 2018г цены оставались примерно на одном уровне(4.5 млн.). 4. В 2019г цены немного выросли до 5 млн. , но так и не достигли показателей 2015г. <br>
# Остается не ясным с чем было связано такое резкое падение цен после 2014г (#возможно с политеческой обстановкой в стране :) #).
# Можно сделать вывод , что цены начали медленно приходить в норму.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Хороший разбор вышел.

# %% [markdown]
# # Изучим 10 населённых пунктах с наибольшим числом объявлений.

# %% [markdown]
# Выделим населенные пункты с наибольшим кол-вом объявлений.

# %%
top_list  = data['locality_name'].value_counts().head(10).index
top_list
# Out:
# Index(['Санкт-Петербург', 'поселок Мурино', 'поселок Шушары', 'Всеволожск',
#        'Пушкин', 'Колпино', 'поселок Парголово', 'Гатчина', 'село Кудрово',
#        'Выборг'],
#       dtype='object')

# %% [markdown]
# Сводная таблица со средей ценой за кв.м для 10 нас. пунктов.

# %%
top_list_pivot = data.query('locality_name in @top_list').pivot_table(index='locality_name', values='square_meter_price')
top_list_pivot.sort_values(by='square_meter_price', ascending=False)
# Out:
#                    square_meter_price
# locality_name
# Санкт-Петербург         111644.020916
# Пушкин                  102929.680714
# село Кудрово             92473.547559
# поселок Парголово        90175.913089
# поселок Мурино           85681.762572
# поселок Шушары           78677.364318
# Колпино                  75333.295816
# Гатчина                  68746.146515
# Всеволожск               68654.473970
# Выборг                   58141.909325

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# Давай с тобой для удобства сделаем сортировку по убыванию. А еще старайся приводить данные к целочисленному формату

# %% [markdown]
# Столбчатый график.

# %%
top_list_pivot.sort_values(by='square_meter_price', ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='locality_name'>

# %% [markdown]
# Как и ожидалось, в Санкт-Петербурге самая высокая цена за кв.м. , в Выборге самая низкая цена за кв.м.

# %% [markdown]
# # Исследуем как меняется цена недвижимости с каждым километром от центра Санкт-Петербурга.

# %% [markdown]
# Сделаем сводную таблицу для города Санкт_петербург. Группировка будет проходить по расстоянию от центра города в км. Посчитаем среднюю цена недвижимости для каждого км.

# %%
center_price_pivot = (
    data.query('locality_name == "Санкт-Петербург"')
    .pivot_table(index='city_center_km', values='last_price', aggfunc='mean')
)
center_price_pivot
# Out:
#                 last_price
# city_center_km
# 0.0              16.592878
# 1.0              12.175725
# 2.0              11.463611
# 3.0               9.916775
# 4.0              10.805913
# 5.0              11.294502
# 6.0              10.650525
# 7.0              10.658817
# 8.0               8.967440
# 9.0               6.950659
# 10.0              6.368644
# 11.0              6.124072
# 12.0              5.787712
# 13.0              6.056588
# 14.0              5.581482
# 15.0              5.809661
# 16.0              5.373131
# 17.0              5.217044
# 18.0              4.904778
# 19.0              5.037675
# 20.0              5.951465
# 21.0              5.493469
# 22.0              5.415524
# 23.0              4.985376
# 24.0              3.854430
# 25.0              4.052840
# 26.0              3.973013
# 27.0              8.300000
# 28.0              5.026429
# 29.0              4.236667

# %%
center_price_pivot.plot.bar() # столбчатый график
# Out:
# <AxesSubplot:xlabel='city_center_km'>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Комментарий ревьюера
#
# #### Успех
#
# Информативная визуализация получилась. После 7-8 км цена перестает сильно падать.

# %% [markdown]
# На графике мы видим, что с большим отрывом самая дорогая недвижимость находится в самом центре города. По мере удаления от центра цена планомерно падает. Исключением является только 27 км , на которм цена находится примерно на уровне 8 км. С чем это связанно не ясно, возможно там распаложен какой то элитный район.

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Для данного проекта были выполненны следующие шаги:
# 1. Обнарауженны и заполненны пропуски там, где это было возможно.
# 2. Был изменен тип данных для формата записи времени.
# 3. Были обнаруженны и исправленны неявные дубликаты в названиях населенных пунктов.
# 4. Также были добавлены новые столбцы (цена одного квадратного метра ,день недели публикации объявления ,месяц публикации объявления, год публикации объявления, тип этажа квартиры, расстояние до центра города в километрах).
# 5. Так же были обработаны редкие и аномальные значения , по возможности исправлены или удалены.
# 6. Выяснилось, что можно считать продажи до месяца достаточно быстрыми. Продажи от 500 дней можно принять за слишком долгие.
# 7. В ходе исследования было выявленны основные факторы влияющие на цену недвижимости : общая площадь недвижимости и жилая площадь.
# 8. Посчитали среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений, а так же где самая высокая и самая низкая цена цена за кв.м : в Санкт-Петербурге самая высокая цена за кв.м. , в Выборге самая низкая цена за кв.м.
# 9. Выявили , как меняется цена за кв.м в Санкт-Петербурге с каждым км от центра : с большим отрывом самая дорогая недвижимость находится в самом центре города. По мере удаления от центра цена планомерно падает. Исключением является только 27 км , на которм цена находится примерно на уровне 8 км. С чем это связанно не ясно, возможно там распаложен какой то элитный район.

# %% [markdown]
# # Рекомендации

# %% [markdown]
# 1. Нужно предзагрусить в систему названия всех нас. пунктов , что бы пользователь выбирал из них. Так можно будет избавиться от возникновения ниявных дубликатов в названиях.
# 2. Так же стоит исключить возможность появления пропусков в данных , например сделать все поля обязательными для заполнения.
# 3. Для самой антифрод-системы стоит разработать отдельный алгоритм для "не типичной недвижимости".

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ### Комментарий ревьюера
#
# #### Совет
#
# В итоговом выводе не хватает рекомендаций. На что бы ты предложил обратить пристальное внимание для составления антифрод-системы Сервиса Недвижимости.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Итоговый комментарии от ревьюера:
#
# #### Успех
#
# Спасибо большое тебе за такую качественную работу. Мне было приятно проверять проект и делиться обратной связью. Особенно впечатлила Предобработка данных. Все достаточно структурировано и последовательно. Ты применяешь верные навыки для работы с кодом. Еще хочу отметить понятные и информативные графики. Однако, в проекте есть несколько замечаний, которые надо исправить:
#
# * Промежуточные выводы добавить.
# * Добавить выводы после графиков.
# * Найти и пояснить выбивающиеся значения на графике по дням в публикации.
#
# Еще я оставил рекомендации. Очень надеюсь, что ты учтешь их в этом и последующих проектах.
#
# Жду проект после доработки. Уверен, ты справишься.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Итоговый Комментарий ревьюера ver.2
#
# #### Успех
#
# Спасибо тебе большое за доработку проекта. Вот теперь я его готов принять. От себя я желаю успехов в дальнешей учебе. Ты точно справишься и дальше, я уверен.

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [ ]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [ ]  в каждом этапе есть промежуточные выводы
# - [ ]  есть общий вывод
